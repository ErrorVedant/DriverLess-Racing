# %%
import pandas as pd
import warnings
warnings.filterwarnings('always')

# %%
df=pd.read_csv("WineQT.csv")
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.250728     0.673157
# volatile acidity          -0.250728          1.000000    -0.544187
# citric acid                0.673157         -0.544187     1.000000
# residual sugar             0.171831         -0.005751     0.175815
# chlorides                  0.107889          0.056336     0.245312
# free sulfur dioxide       -0.164831         -0.001962    -0.057589
# total sulfur dioxide      -0.110628          0.077748     0.036871
# density                    0.681501          0.016512     0.375243
# pH                        -0.685163          0.221492    -0.546339
# sulphates                  0.174592         -0.276079     0.331232
# alcohol                   -0.075055         -0.203909     0.106250
# quality                    0.121970         -0.407394     0.240821
# Id                        -0.275826         -0.007892    -0.139011
#
# ...

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'Id'],
#       dtype='object')

# %% [markdown]
# <h1>CLEANING THE DATA<hi/>

# %%
from sklearn import datasets,linear_model
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR

# %%
y=df['quality']
X=df.drop(['quality'],axis=1)

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X)
StandardScaler()
a=scaler.transform(X)

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'Id'],
#       dtype='object')

# %%
X= pd.DataFrame(a,columns=['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol', 'Id'])
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0         -0.521580          0.939332    -1.365027       -0.466421  -0.231395
# 1         -0.292593          1.941813    -1.365027        0.050060   0.234247
# 2         -0.292593          1.273492    -1.161568       -0.171289   0.107253
# 3          1.653789         -1.399789     1.483400       -0.466421  -0.252560
# 4         -0.521580          0.939332    -1.365027       -0.466421  -0.231395
# ...             ...               ...          ...             ...        ...
# 1138      -1.151292         -0.118842    -0.703785       -0.171289  -0.231395
# 1139      -0.865059          0.493785    -0.958109       -0.466421  -0.400719
# 1140      -1.208538          0.382399    -0.958109       -0.392638   0.064922
# 1141      -1.380278          0.103932    -0.856379       -0.245072  -0.527712
# 1142      -1.380278          0.633019    -0.754650       -0.392638  -0.252560
#
# ...

# %%
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1138    6
# 1139    6
# 1140    5
# 1141    6
# 1142    5
# Name: quality, Length: 1143, dtype: int64

# %%
X_train, X_test, y_train, y_test=train_test_split(X,y,random_state=104,test_size=0.3,shuffle=True)

# %%
X_train
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 989      -0.178100         -0.063148    -0.093408       -0.392638  -0.189064
# 661      -0.979552          0.438092    -1.314162       -0.466421  -0.146733
# 623       0.279872          0.438092    -0.398596        1.083023   0.149584
# 235       0.050886          0.159625    -0.958109       -0.318855   0.382405
# 232       1.882775         -0.007455     1.992047        0.824783   0.721053
# ..             ...               ...          ...             ...        ...
# 520       0.680598          0.103932     1.992047       -0.171289   6.351082
# 166      -0.636073          0.549479    -1.365027       -0.466421   0.213081
# 654       0.165379         -1.733949     0.466104       -0.466421  -0.485381
# 729       0.222625         -0.675775     0.720428        2.706251  -0.189064
# 69       -0.120854          0.076085    -0.449461       -0.466421  -0.146733
#
# ...

# %%
y_train
# Out:
# 989    5
# 661    5
# 623    6
# 235    5
# 232    7
#       ..
# 520    5
# 166    6
# 654    7
# 729    7
# 69     6
# Name: quality, Length: 800, dtype: int64

# %%
# from sklearn.tree import DecisionTreeClassifier
# dtc_model = DecisionTreeClassifier(max_depth = 6, random_state = 10)
# dtc_model.fit(X_train, y_train)

# svr = SVR(kernel='rbf') 
# svr.fit(X_train, y_train) 

from sklearn.linear_model import LinearRegression
regr = LinearRegression()
regr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_test
# Out:
# 705     7
# 588     5
# 850     8
# 596     4
# 98      6
#        ..
# 117     5
# 1081    6
# 863     6
# 132     6
# 381     6
# Name: quality, Length: 343, dtype: int64

# %%
y_pred = regr.predict(X_test)
y_p=[]
for k in y_pred:
    y_p.append(round(k))
y_p
# Out:
# [7,
#  5,
#  6,
#  6,
#  7,
#  5,
#  5,
#  5,
#  5,
#  6,
#  6,
#  5,
#  5,
#  6,
#  6,
#  5,
#  6,
#  6,
#  5,
#  6,
#  5,
#  5,
#  6,
#  6,
#  5,
#  5,
#  5,
#  5,
#  6,
#  5,
#  5,
#  5,
#  7,
#  5,
#  5,
#  5,
#  6,
#  6,
#  5,
#  5,
#  5,
#  5,
#  5,
#  6,
#  6,
#  5,
#  6,
#  6,
#  5,
#  5,
#  5,
#  5,
#  6,
#  6,
#  6,
#  6,
#  5,
#  6,
#  5,
#  5,
#  6,
#  6,
#  6,
#  4,
#  6,
#  5,
#  5,
#  5,
#  6,
#  5,
#  6,
#  6,
#  7,
#  5,
#  6,
#  6,
#  5,
#  5,
#  5,
#  6,
#  6,
#  6,
#  6,
#  6,
#  5,
#  5,
#  5,
#  5,
#  6,
#  6,
#  5,
#  4,
#  6,
#  6,
#  5,
#  6,
#  5,
#  5,
#  5,
#  6,
#  6,
#  6,
#  5,
#  6,
#  5,
#  6,
#  6,
#  6,
#  5,
#  5,
#  5,
#  6,
#  5,
#  6,
#  5,
#  6,
#  5,
#  5,
#  5,
#  6,
#  5,
#  6,
#  6,
#  6,
#  6,
#  6,
#  7,
#  6,
#  7,
#  5,
#  5,
#  5,
#  6,
#  6,
#  5,
#  5,
#  5,
#  6,
#  6,
#  5,
#  6,
#  5,
#  6,
#  5,
#  5,
#  6,
#  5,
#  5,
#  6,
#  7,
#  5,
#  5,
#  8,
#  6,
#  6,
#  6,
#  5,
#  5,
#  6,
#  6,
#  5,
#  5,
#  5,
#  6,
#  6,
#  5,
# ...

# %%
import matplotlib.pyplot as plt

plt.scatter(y_p, y_test, color ='b')
plt.show()

# %%
print(classification_report(y_p,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         0
#            4       0.00      0.00      0.00         2
#            5       0.73      0.68      0.71       161
#            6       0.64      0.52      0.57       160
#            7       0.24      0.53      0.33        19
#            8       0.00      0.00      0.00         1
#
#     accuracy                           0.59       343
#    macro avg       0.27      0.29      0.27       343
# weighted avg       0.65      0.59      0.62       343
# C:\Users\vedan\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
